# %%
import numpy
import seaborn as sns
from bootstrapper import Bootstrapper

# %%
sample = numpy.random.randn(1024)
b = Bootstrapper(bootstrap_count=1024)
means = b.run(lambda array: array.mean(), sample)

# %%
sns.set()
sns.distplot(means, kde=True);
